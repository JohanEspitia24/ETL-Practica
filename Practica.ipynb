# %%
import os # import the os module

items = os.listdir() # get all items in the current directory
items
# Out:
# ['.git', '.gitattributes', 'Practica.ipynb']

# %%
items = os.listdir('E:\Programas') # get all items in the directory 'E:\Programas'
items
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\johan\AppData\Local\Temp\ipykernel_23212\3884183481.py:1: SyntaxWarning: invalid escape sequence '\P'
#   items = os.listdir('E:\Programas') # get all items in the directory 'E:\Programas'
# ['Androidd Studio',
#  'apache-maven-3.9.9',
#  'Bizagi',
#  'corepack',
#  'corepack.cmd',
#  'DbgPlugInDiggers.dll',
#  'DLLs',
#  'Doc',
#  'Docker Desktop Installer.exe',
#  'drivers',
#  'dtrace',
#  'ExtensionPacks',
#  'Git',
#  'gradle-8.5',
#  'gradle-8.7',
#  'include',
#  'install_tools.bat',
#  'IntelliJ IDEA Community Edition 2024.3',
#  'jdk-17.0.12_windows-x64_bin',
#  'Lib',
#  'libs',
#  'LICENSE.txt',
#  'License_en_US.rtf',
#  'Microsoft VS Code',
#  'MSYS2',
#  'NEWS.txt',
#  'nls',
#  'node.exe',
#  'nodevars.bat',
#  'node_modules',
#  'npm',
#  'npm.cmd',
#  'npx',
#  'npx.cmd',
#  'platforms',
#  'python.exe',
#  'python.pdb',
#  'python3.dll',
#  'python312.dll',
#  'python312.pdb',
#  'python312_d.dll',
#  'python312_d.pdb',
#  'python3_d.dll',
#  'pythonw.exe',
#  'pythonw.pdb',
#  'pythonw_d.exe',
#  'pythonw_d.pdb',
#  'python_d.exe',
#  'python_d.pdb',
#  'Qt6CoreVBox.dll',
#  'Qt6GuiVBox.dll',
#  'Qt6HelpVBox.dll',
#  'Qt6PrintSupportVBox.dll',
#  'Qt6SqlVBox.dll',
#  'Qt6StateMachineVBox.dll',
#  'Qt6WidgetsVBox.dll',
#  'R-4.4.1',
#  'RStudio',
#  'sdk',
#  'sqldrivers',
#  'styles',
#  'tcl',
#  'UICommon.dll',
#  'UnattendedTemplates',
#  'UserManual.qch',
#  'UserManual.qhc',
#  'vbox-img.exe',
#  'VBoxAudioTest.exe',
#  'VBoxAuth.dll',
#  'VBoxAuthSimple.dll',
#  'VBoxAutostartSvc.exe',
#  'VBoxBalloonCtrl.exe',
#  'VBoxBugReport.exe',
#  'VBoxC.dll',
#  'VBoxCAPI.dll',
#  'VBoxDbg.dll',
#  'VBoxDD.dll',
#  'VBoxDD2.dll',
#  'VBoxDDR0.r0',
#  'VBoxDDU.dll',
#  'VBoxDragAndDropSvc.dll',
#  'VBoxDTrace.exe',
#  'VBoxExtPackHelperApp.exe',
#  'VBoxGuestAdditions.iso',
#  'VBoxGuestControlSvc.dll',
#  'VBoxGuestPropSvc.dll',
#  'VBoxHeadless.dll',
#  'VBoxHeadless.exe',
#  'VBoxHostChannel.dll',
#  'VBoxLibSsh.dll',
#  'VBoxManage.exe',
#  'VBoxNetDHCP.dll',
#  'VBoxNetDHCP.exe',
#  'VBoxNetNAT.dll',
#  'VBoxNetNAT.exe',
#  'VBoxProxyStub.dll',
#  'VBoxRes.dll',
#  'VBoxRT.dll',
#  'VBoxSDS.exe',
#  'VBoxSharedClipboard.dll',
#  'VBoxSharedFolders.dll',
#  'VBoxSupLib.dll',
#  'VBoxSVC.exe',
#  'VBoxVMM.dll',
#  'VBoxWebSrv.exe',
#  'vcruntime140.dll',
#  'vcruntime140_1.dll',
#  'VirtualBox.exe',
#  'VirtualBox.VisualElementsManifest.xml',
#  'VirtualBoxVM.dll',
#  'VirtualBoxVM.exe',
#  'VirtualBox_150px.png',
#  'VirtualBox_70px.png',
#  'VMMR0.r0',
#  'x86']

# %%
mypath = 'E:\Programas'
items = [os.path.join(mypath, f) for f in os.listdir(mypath)] # get all items in the directory 'E:\Programas' with the full path
items
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\johan\AppData\Local\Temp\ipykernel_23212\3488262940.py:1: SyntaxWarning: invalid escape sequence '\P'
#   mypath = 'E:\Programas'
# ['E:\\Programas\\Androidd Studio',
#  'E:\\Programas\\apache-maven-3.9.9',
#  'E:\\Programas\\Bizagi',
#  'E:\\Programas\\corepack',
#  'E:\\Programas\\corepack.cmd',
#  'E:\\Programas\\DbgPlugInDiggers.dll',
#  'E:\\Programas\\DLLs',
#  'E:\\Programas\\Doc',
#  'E:\\Programas\\Docker Desktop Installer.exe',
#  'E:\\Programas\\drivers',
#  'E:\\Programas\\dtrace',
#  'E:\\Programas\\ExtensionPacks',
#  'E:\\Programas\\Git',
#  'E:\\Programas\\gradle-8.5',
#  'E:\\Programas\\gradle-8.7',
#  'E:\\Programas\\include',
#  'E:\\Programas\\install_tools.bat',
#  'E:\\Programas\\IntelliJ IDEA Community Edition 2024.3',
#  'E:\\Programas\\jdk-17.0.12_windows-x64_bin',
#  'E:\\Programas\\Lib',
#  'E:\\Programas\\libs',
#  'E:\\Programas\\LICENSE.txt',
#  'E:\\Programas\\License_en_US.rtf',
#  'E:\\Programas\\Microsoft VS Code',
#  'E:\\Programas\\MSYS2',
#  'E:\\Programas\\NEWS.txt',
#  'E:\\Programas\\nls',
#  'E:\\Programas\\node.exe',
#  'E:\\Programas\\nodevars.bat',
#  'E:\\Programas\\node_modules',
#  'E:\\Programas\\npm',
#  'E:\\Programas\\npm.cmd',
#  'E:\\Programas\\npx',
#  'E:\\Programas\\npx.cmd',
#  'E:\\Programas\\platforms',
#  'E:\\Programas\\python.exe',
#  'E:\\Programas\\python.pdb',
#  'E:\\Programas\\python3.dll',
#  'E:\\Programas\\python312.dll',
#  'E:\\Programas\\python312.pdb',
#  'E:\\Programas\\python312_d.dll',
#  'E:\\Programas\\python312_d.pdb',
#  'E:\\Programas\\python3_d.dll',
#  'E:\\Programas\\pythonw.exe',
#  'E:\\Programas\\pythonw.pdb',
#  'E:\\Programas\\pythonw_d.exe',
#  'E:\\Programas\\pythonw_d.pdb',
#  'E:\\Programas\\python_d.exe',
#  'E:\\Programas\\python_d.pdb',
#  'E:\\Programas\\Qt6CoreVBox.dll',
#  'E:\\Programas\\Qt6GuiVBox.dll',
#  'E:\\Programas\\Qt6HelpVBox.dll',
#  'E:\\Programas\\Qt6PrintSupportVBox.dll',
#  'E:\\Programas\\Qt6SqlVBox.dll',
#  'E:\\Programas\\Qt6StateMachineVBox.dll',
#  'E:\\Programas\\Qt6WidgetsVBox.dll',
#  'E:\\Programas\\R-4.4.1',
#  'E:\\Programas\\RStudio',
#  'E:\\Programas\\sdk',
#  'E:\\Programas\\sqldrivers',
#  'E:\\Programas\\styles',
#  'E:\\Programas\\tcl',
#  'E:\\Programas\\UICommon.dll',
#  'E:\\Programas\\UnattendedTemplates',
#  'E:\\Programas\\UserManual.qch',
#  'E:\\Programas\\UserManual.qhc',
#  'E:\\Programas\\vbox-img.exe',
#  'E:\\Programas\\VBoxAudioTest.exe',
#  'E:\\Programas\\VBoxAuth.dll',
#  'E:\\Programas\\VBoxAuthSimple.dll',
#  'E:\\Programas\\VBoxAutostartSvc.exe',
#  'E:\\Programas\\VBoxBalloonCtrl.exe',
#  'E:\\Programas\\VBoxBugReport.exe',
#  'E:\\Programas\\VBoxC.dll',
#  'E:\\Programas\\VBoxCAPI.dll',
#  'E:\\Programas\\VBoxDbg.dll',
#  'E:\\Programas\\VBoxDD.dll',
#  'E:\\Programas\\VBoxDD2.dll',
#  'E:\\Programas\\VBoxDDR0.r0',
#  'E:\\Programas\\VBoxDDU.dll',
#  'E:\\Programas\\VBoxDragAndDropSvc.dll',
#  'E:\\Programas\\VBoxDTrace.exe',
#  'E:\\Programas\\VBoxExtPackHelperApp.exe',
#  'E:\\Programas\\VBoxGuestAdditions.iso',
#  'E:\\Programas\\VBoxGuestControlSvc.dll',
#  'E:\\Programas\\VBoxGuestPropSvc.dll',
#  'E:\\Programas\\VBoxHeadless.dll',
#  'E:\\Programas\\VBoxHeadless.exe',
#  'E:\\Programas\\VBoxHostChannel.dll',
#  'E:\\Programas\\VBoxLibSsh.dll',
#  'E:\\Programas\\VBoxManage.exe',
#  'E:\\Programas\\VBoxNetDHCP.dll',
#  'E:\\Programas\\VBoxNetDHCP.exe',
#  'E:\\Programas\\VBoxNetNAT.dll',
#  'E:\\Programas\\VBoxNetNAT.exe',
#  'E:\\Programas\\VBoxProxyStub.dll',
#  'E:\\Programas\\VBoxRes.dll',
#  'E:\\Programas\\VBoxRT.dll',
#  'E:\\Programas\\VBoxSDS.exe',
#  'E:\\Programas\\VBoxSharedClipboard.dll',
#  'E:\\Programas\\VBoxSharedFolders.dll',
#  'E:\\Programas\\VBoxSupLib.dll',
#  'E:\\Programas\\VBoxSVC.exe',
#  'E:\\Programas\\VBoxVMM.dll',
#  'E:\\Programas\\VBoxWebSrv.exe',
#  'E:\\Programas\\vcruntime140.dll',
#  'E:\\Programas\\vcruntime140_1.dll',
#  'E:\\Programas\\VirtualBox.exe',
#  'E:\\Programas\\VirtualBox.VisualElementsManifest.xml',
#  'E:\\Programas\\VirtualBoxVM.dll',
#  'E:\\Programas\\VirtualBoxVM.exe',
#  'E:\\Programas\\VirtualBox_150px.png',
#  'E:\\Programas\\VirtualBox_70px.png',
#  'E:\\Programas\\VMMR0.r0',
#  'E:\\Programas\\x86']

# %%
import os
from os import path

mypath = 'E:\Programas'
items = [f for f in os.listdir(mypath) if path.isfile(path.join(mypath ,f )) ]
 # get all files in the directory 'E:\Programas'
items
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\johan\AppData\Local\Temp\ipykernel_23212\4195670629.py:4: SyntaxWarning: invalid escape sequence '\P'
#   mypath = 'E:\Programas'
# ['corepack',
#  'corepack.cmd',
#  'DbgPlugInDiggers.dll',
#  'Docker Desktop Installer.exe',
#  'install_tools.bat',
#  'LICENSE.txt',
#  'License_en_US.rtf',
#  'NEWS.txt',
#  'node.exe',
#  'nodevars.bat',
#  'npm',
#  'npm.cmd',
#  'npx',
#  'npx.cmd',
#  'python.exe',
#  'python.pdb',
#  'python3.dll',
#  'python312.dll',
#  'python312.pdb',
#  'python312_d.dll',
#  'python312_d.pdb',
#  'python3_d.dll',
#  'pythonw.exe',
#  'pythonw.pdb',
#  'pythonw_d.exe',
#  'pythonw_d.pdb',
#  'python_d.exe',
#  'python_d.pdb',
#  'Qt6CoreVBox.dll',
#  'Qt6GuiVBox.dll',
#  'Qt6HelpVBox.dll',
#  'Qt6PrintSupportVBox.dll',
#  'Qt6SqlVBox.dll',
#  'Qt6StateMachineVBox.dll',
#  'Qt6WidgetsVBox.dll',
#  'UICommon.dll',
#  'UserManual.qch',
#  'UserManual.qhc',
#  'vbox-img.exe',
#  'VBoxAudioTest.exe',
#  'VBoxAuth.dll',
#  'VBoxAuthSimple.dll',
#  'VBoxAutostartSvc.exe',
#  'VBoxBalloonCtrl.exe',
#  'VBoxBugReport.exe',
#  'VBoxC.dll',
#  'VBoxCAPI.dll',
#  'VBoxDbg.dll',
#  'VBoxDD.dll',
#  'VBoxDD2.dll',
#  'VBoxDDR0.r0',
#  'VBoxDDU.dll',
#  'VBoxDragAndDropSvc.dll',
#  'VBoxDTrace.exe',
#  'VBoxExtPackHelperApp.exe',
#  'VBoxGuestAdditions.iso',
#  'VBoxGuestControlSvc.dll',
#  'VBoxGuestPropSvc.dll',
#  'VBoxHeadless.dll',
#  'VBoxHeadless.exe',
#  'VBoxHostChannel.dll',
#  'VBoxLibSsh.dll',
#  'VBoxManage.exe',
#  'VBoxNetDHCP.dll',
#  'VBoxNetDHCP.exe',
#  'VBoxNetNAT.dll',
#  'VBoxNetNAT.exe',
#  'VBoxProxyStub.dll',
#  'VBoxRes.dll',
#  'VBoxRT.dll',
#  'VBoxSDS.exe',
#  'VBoxSharedClipboard.dll',
#  'VBoxSharedFolders.dll',
#  'VBoxSupLib.dll',
#  'VBoxSVC.exe',
#  'VBoxVMM.dll',
#  'VBoxWebSrv.exe',
#  'vcruntime140.dll',
#  'vcruntime140_1.dll',
#  'VirtualBox.exe',
#  'VirtualBox.VisualElementsManifest.xml',
#  'VirtualBoxVM.dll',
#  'VirtualBoxVM.exe',
#  'VirtualBox_150px.png',
#  'VirtualBox_70px.png',
#  'VMMR0.r0']

# %%
import os
from os import path

mypath = 'E:\Programas'
items = [f for f in os.listdir(mypath) if path.isdir(path.join(mypath ,f )) ]
    # get all directories in the directory 'E:\Programas'
items
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\johan\AppData\Local\Temp\ipykernel_23212\826940283.py:4: SyntaxWarning: invalid escape sequence '\P'
#   mypath = 'E:\Programas'
# ['Androidd Studio',
#  'apache-maven-3.9.9',
#  'Bizagi',
#  'DLLs',
#  'Doc',
#  'drivers',
#  'dtrace',
#  'ExtensionPacks',
#  'Git',
#  'gradle-8.5',
#  'gradle-8.7',
#  'include',
#  'IntelliJ IDEA Community Edition 2024.3',
#  'jdk-17.0.12_windows-x64_bin',
#  'Lib',
#  'libs',
#  'Microsoft VS Code',
#  'MSYS2',
#  'nls',
#  'node_modules',
#  'platforms',
#  'R-4.4.1',
#  'RStudio',
#  'sdk',
#  'sqldrivers',
#  'styles',
#  'tcl',
#  'UnattendedTemplates',
#  'x86']

# %%
import glob # import the glob module

list = glob.glob('E:\Programas\*.dll') # get all items in the directory 'E:\Programas' with the extension .dll
list
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\johan\AppData\Local\Temp\ipykernel_23212\4293789841.py:3: SyntaxWarning: invalid escape sequence '\P'
#   list = glob.glob('E:\Programas\*.dll') # get all items in the directory 'E:\Programas' with the extension .dll
# ['E:\\Programas\\DbgPlugInDiggers.dll',
#  'E:\\Programas\\python3.dll',
#  'E:\\Programas\\python312.dll',
#  'E:\\Programas\\python312_d.dll',
#  'E:\\Programas\\python3_d.dll',
#  'E:\\Programas\\Qt6CoreVBox.dll',
#  'E:\\Programas\\Qt6GuiVBox.dll',
#  'E:\\Programas\\Qt6HelpVBox.dll',
#  'E:\\Programas\\Qt6PrintSupportVBox.dll',
#  'E:\\Programas\\Qt6SqlVBox.dll',
#  'E:\\Programas\\Qt6StateMachineVBox.dll',
#  'E:\\Programas\\Qt6WidgetsVBox.dll',
#  'E:\\Programas\\UICommon.dll',
#  'E:\\Programas\\VBoxAuth.dll',
#  'E:\\Programas\\VBoxAuthSimple.dll',
#  'E:\\Programas\\VBoxC.dll',
#  'E:\\Programas\\VBoxCAPI.dll',
#  'E:\\Programas\\VBoxDbg.dll',
#  'E:\\Programas\\VBoxDD.dll',
#  'E:\\Programas\\VBoxDD2.dll',
#  'E:\\Programas\\VBoxDDU.dll',
#  'E:\\Programas\\VBoxDragAndDropSvc.dll',
#  'E:\\Programas\\VBoxGuestControlSvc.dll',
#  'E:\\Programas\\VBoxGuestPropSvc.dll',
#  'E:\\Programas\\VBoxHeadless.dll',
#  'E:\\Programas\\VBoxHostChannel.dll',
#  'E:\\Programas\\VBoxLibSsh.dll',
#  'E:\\Programas\\VBoxNetDHCP.dll',
#  'E:\\Programas\\VBoxNetNAT.dll',
#  'E:\\Programas\\VBoxProxyStub.dll',
#  'E:\\Programas\\VBoxRes.dll',
#  'E:\\Programas\\VBoxRT.dll',
#  'E:\\Programas\\VBoxSharedClipboard.dll',
#  'E:\\Programas\\VBoxSharedFolders.dll',
#  'E:\\Programas\\VBoxSupLib.dll',
#  'E:\\Programas\\VBoxVMM.dll',
#  'E:\\Programas\\vcruntime140.dll',
#  'E:\\Programas\\vcruntime140_1.dll',
#  'E:\\Programas\\VirtualBoxVM.dll']

# %%
import os
from os import path
import shutil

def listing(mypath):
    items = [os.path.join(mypath, f) for f in os.listdir(mypath)]
    for item in items:
        print(item)

#Create a folder
print('Create a folder')
dir_path = 'E:/Programas/myfolder'

try:
    if not path.exists(dir_path):
        os.makedirs(dir_path)
except PermissionError:
    print('Acceso denegado por permisos de administrador')
listing('E:/Programas')
print('')
# Out:
# Create a folder
# Acceso denegado por permisos de administrador
# E:/Programas\Androidd Studio
# E:/Programas\apache-maven-3.9.9
# E:/Programas\Bizagi
# E:/Programas\corepack
# E:/Programas\corepack.cmd
# E:/Programas\DbgPlugInDiggers.dll
# E:/Programas\DLLs
# E:/Programas\Doc
# E:/Programas\Docker Desktop Installer.exe
# E:/Programas\drivers
# E:/Programas\dtrace
# E:/Programas\ExtensionPacks
# E:/Programas\Git
# E:/Programas\gradle-8.5
# E:/Programas\gradle-8.7
# E:/Programas\include
# E:/Programas\install_tools.bat
# E:/Programas\IntelliJ IDEA Community Edition 2024.3
# E:/Programas\jdk-17.0.12_windows-x64_bin
# E:/Programas\Lib
# E:/Programas\libs
# E:/Programas\LICENSE.txt
# E:/Programas\License_en_US.rtf
# E:/Programas\Microsoft VS Code
# E:/Programas\MSYS2
# E:/Programas\NEWS.txt
# E:/Programas\nls
# E:/Programas\node.exe
# E:/Programas\nodevars.bat
# E:/Programas\node_modules
# E:/Programas\npm
# E:/Programas\npm.cmd
# E:/Programas\npx
# E:/Programas\npx.cmd
# E:/Programas\platforms
# E:/Programas\python.exe
# E:/Programas\python.pdb
# E:/Programas\python3.dll
# E:/Programas\python312.dll
# E:/Programas\python312.pdb
# E:/Programas\python312_d.dll
# E:/Programas\python312_d.pdb
# E:/Programas\python3_d.dll
# E:/Programas\pythonw.exe
# E:/Programas\pythonw.pdb
# E:/Programas\pythonw_d.exe
# E:/Programas\pythonw_d.pdb
# E:/Programas\python_d.exe
# E:/Programas\python_d.pdb
# E:/Programas\Qt6CoreVBox.dll
# E:/Programas\Qt6GuiVBox.dll
# E:/Programas\Qt6HelpVBox.dll
# E:/Programas\Qt6PrintSupportVBox.dll
# E:/Programas\Qt6SqlVBox.dll
# E:/Programas\Qt6StateMachineVBox.dll
# E:/Programas\Qt6WidgetsVBox.dll
# E:/Programas\R-4.4.1
# E:/Programas\RStudio
# E:/Programas\sdk
# E:/Programas\sqldrivers
# E:/Programas\styles
# E:/Programas\tcl
# E:/Programas\UICommon.dll
# E:/Programas\UnattendedTemplates
# E:/Programas\UserManual.qch
# E:/Programas\UserManual.qhc
# E:/Programas\vbox-img.exe
# E:/Programas\VBoxAudioTest.exe
# E:/Programas\VBoxAuth.dll
# E:/Programas\VBoxAuthSimple.dll
# E:/Programas\VBoxAutostartSvc.exe
# E:/Programas\VBoxBalloonCtrl.exe
# E:/Programas\VBoxBugReport.exe
# E:/Programas\VBoxC.dll
# E:/Programas\VBoxCAPI.dll
# E:/Programas\VBoxDbg.dll
# E:/Programas\VBoxDD.dll
# E:/Programas\VBoxDD2.dll
# E:/Programas\VBoxDDR0.r0
# E:/Programas\VBoxDDU.dll
# E:/Programas\VBoxDragAndDropSvc.dll
# E:/Programas\VBoxDTrace.exe
# E:/Programas\VBoxExtPackHelperApp.exe
# E:/Programas\VBoxGuestAdditions.iso
# E:/Programas\VBoxGuestControlSvc.dll
# E:/Programas\VBoxGuestPropSvc.dll
# E:/Programas\VBoxHeadless.dll
# E:/Programas\VBoxHeadless.exe
# E:/Programas\VBoxHostChannel.dll
# E:/Programas\VBoxLibSsh.dll
# E:/Programas\VBoxManage.exe
# E:/Programas\VBoxNetDHCP.dll
# E:/Programas\VBoxNetDHCP.exe
# E:/Programas\VBoxNetNAT.dll
# E:/Programas\VBoxNetNAT.exe
# E:/Programas\VBoxProxyStub.dll
# E:/Programas\VBoxRes.dll
# E:/Programas\VBoxRT.dll
# E:/Programas\VBoxSDS.exe
# E:/Programas\VBoxSharedClipboard.dll
# E:/Programas\VBoxSharedFolders.dll
# E:/Programas\VBoxSupLib.dll
# E:/Programas\VBoxSVC.exe
# E:/Programas\VBoxVMM.dll
# E:/Programas\VBoxWebSrv.exe
# E:/Programas\vcruntime140.dll
# E:/Programas\vcruntime140_1.dll
# E:/Programas\VirtualBox.exe
# E:/Programas\VirtualBox.VisualElementsManifest.xml
# E:/Programas\VirtualBoxVM.dll
# E:/Programas\VirtualBoxVM.exe
# E:/Programas\VirtualBox_150px.png
# E:/Programas\VirtualBox_70px.png
# E:/Programas\VMMR0.r0
# E:/Programas\x86
