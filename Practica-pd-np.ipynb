# %%
import pandas as pd
import numpy as np

# %%
pd.__version__, 
np.__version__
# Out:
# '2.1.2'

# %%
#Reading csv files
df = pd.read_csv('C:/Users/johan/Documents/new_folder/Rename_Energy.csv') 
df
# Out:
#       ObjectId             Country ISO2   ISO3  \
# 0            1  Advanced Economies  NaN  AETMP
# 1            2  Advanced Economies  NaN  AETMP
# 2            3  Advanced Economies  NaN  AETMP
# 3            4  Advanced Economies  NaN  AETMP
# 4            5  Advanced Economies  NaN  AETMP
# ...        ...                 ...  ...    ...
# 2057      2058            Zimbabwe   ZW    ZWE
# 2058      2059            Zimbabwe   ZW    ZWE
# 2059      2060            Zimbabwe   ZW    ZWE
# 2060      2061            Zimbabwe   ZW    ZWE
# 2061      2062            Zimbabwe   ZW    ZWE
#
#                            Indicator                         Technology  \
# 0             Electricity Generation                          Bioenergy
# 1     Electricity Installed Capacity                          Bioenergy
# 2             Electricity Generation                       Fossil fuels
# 3     Electricity Installed Capacity                       Fossil fuels
# ...

# %%
#writing to csv files
df.to_csv('C:/Users/johan/Documents/new_folder/Rename_Energy.csv', sep=';', index=False)
